# %%
import pandas as pd

# %%
dataset=pd.read_csv(r'F:\WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
dataset.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
dataset.shape
# Out:
# (1470, 35)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
dataset.shape
# Out:
# (1470, 35)

# %%
dataset1=dataset.dropna()

# %%
dataset1.shape
# Out:
# (1470, 35)

# %%
dataset2=dataset1.drop_duplicates()

# %%
dataset2.shape
# Out:
# (1470, 35)

# %%
dataset2.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
import statistics

# %%
dataset2 [['Age',
       'DistanceFromHome', 'Education',  'MonthlyIncome', 'NumCompaniesWorked','PercentSalaryHike',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany' , 'YearsSinceLastPromotion',
       'YearsWithCurrManager']]. min()
# Out:
# Age                          18
# DistanceFromHome              1
# Education                     1
# MonthlyIncome              1009
# NumCompaniesWorked            0
# PercentSalaryHike            11
# TotalWorkingYears             0
# TrainingTimesLastYear         0
# YearsAtCompany                0
# YearsSinceLastPromotion       0
# YearsWithCurrManager          0
# dtype: int64

# %%
dataset2 [['Age',
       'DistanceFromHome', 'Education',  'MonthlyIncome', 'NumCompaniesWorked','PercentSalaryHike',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany' , 'YearsSinceLastPromotion',
       'YearsWithCurrManager']]. max()
# Out:
# Age                           60
# DistanceFromHome              29
# Education                      5
# MonthlyIncome              19999
# NumCompaniesWorked             9
# PercentSalaryHike             25
# TotalWorkingYears             40
# TrainingTimesLastYear          6
# YearsAtCompany                40
# YearsSinceLastPromotion       15
# YearsWithCurrManager          17
# dtype: int64

# %%
dataset2 [['Age',
       'DistanceFromHome', 'Education',  'MonthlyIncome', 'NumCompaniesWorked','PercentSalaryHike',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany' , 'YearsSinceLastPromotion',
       'YearsWithCurrManager']].mean()
# Out:
# Age                          36.923810
# DistanceFromHome              9.192517
# Education                     2.912925
# MonthlyIncome              6502.931293
# NumCompaniesWorked            2.693197
# PercentSalaryHike            15.209524
# TotalWorkingYears            11.279592
# TrainingTimesLastYear         2.799320
# YearsAtCompany                7.008163
# YearsSinceLastPromotion       2.187755
# YearsWithCurrManager          4.123129
# dtype: float64

# %%
dataset2 [['Age',
       'DistanceFromHome', 'Education',  'MonthlyIncome', 'NumCompaniesWorked','PercentSalaryHike',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany' , 'YearsSinceLastPromotion',
       'YearsWithCurrManager']].skew()
# Out:
# Age                        0.413286
# DistanceFromHome           0.958118
# Education                 -0.289681
# MonthlyIncome              1.369817
# NumCompaniesWorked         1.026471
# PercentSalaryHike          0.821128
# TotalWorkingYears          1.117172
# TrainingTimesLastYear      0.553124
# YearsAtCompany             1.764529
# YearsSinceLastPromotion    1.984290
# YearsWithCurrManager       0.833451
# dtype: float64

# %%
dataset[['Age',
       'DistanceFromHome', 'Education',  'MonthlyIncome', 'NumCompaniesWorked','PercentSalaryHike',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany' , 'YearsSinceLastPromotion',
       'YearsWithCurrManager']].kurt()
# Out:
# Age                       -0.404145
# DistanceFromHome          -0.224833
# Education                 -0.559115
# MonthlyIncome              1.005233
# NumCompaniesWorked         0.010214
# PercentSalaryHike         -0.300598
# TotalWorkingYears          0.918270
# TrainingTimesLastYear      0.494993
# YearsAtCompany             3.935509
# YearsSinceLastPromotion    3.612673
# YearsWithCurrManager       0.171058
# dtype: float64

# %%
dataset3=dataset2[['Age',
       'DistanceFromHome', 'Education',  'MonthlyIncome', 'NumCompaniesWorked','PercentSalaryHike',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany' , 'YearsSinceLastPromotion',
       'YearsWithCurrManager']]

# %%
dataset3.head()
# Out:
#    Age  DistanceFromHome  Education  MonthlyIncome  NumCompaniesWorked  \
# 0   41                 1          2           5993                   8
# 1   49                 8          1           5130                   1
# 2   37                 2          2           2090                   6
# 3   33                 3          4           2909                   1
# 4   27                 2          1           3468                   9
#
#    PercentSalaryHike  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 11                  8                      0
# 1                 23                 10                      3
# 2                 15                  7                      3
# 3                 11                  8                      3
# 4                 12                  6                      3
#
#    YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager
# 0               6                        0                     5
# ...

# %%
dataset3.shape
# Out:
# (1470, 11)

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(dataset2.Age)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23dcca956f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23dcca95c30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23dcca95450>],
#  'medians': [<matplotlib.lines.Line2D at 0x23dcca96170>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23dcca96410>],
#  'means': []}

# %%
plt.boxplot(dataset2.MonthlyIncome)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23dccb76a70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23dccbac2b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23dccb77bb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x23dccbac7f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23dccbaca90>],
#  'means': []}

# %%
plt.boxplot(dataset2.YearsAtCompany )
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23dccc28100>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23dccc28640>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23dccbffe20>],
#  'medians': [<matplotlib.lines.Line2D at 0x23dccc28b20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23dccc28dc0>],
#  'means': []}

# %%
from sklearn import preprocessing

# %%
le=preprocessing.LabelEncoder()

# %%
dataset2["Attrition"]=le.fit_transform(dataset2["Attrition"])

# %%
dataset2["EducationField"]=le.fit_transform(dataset2["EducationField"])

# %%
dataset2["Department"]=le.fit_transform(dataset2["Department"])

# %%
dataset2["BusinessTravel"]=le.fit_transform(dataset2["BusinessTravel"])

# %%
dataset2["Gender "]=le.fit_transform(dataset2["Gender"])

# %%
dataset2["MaritalStatus"]=le.fit_transform(dataset2["MaritalStatus"])

# %%
dataset2["JobRole"]=le.fit_transform(dataset2["JobRole"])

# %%
dataset2.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2               1              1               1  ...
# 1          1               1              1               2  ...
# 2          2               4              1               4  ...
# 3          4               1              1               5  ...
# 4          1               3              1               7  ...
#
#    StandardHours StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# ...

# %%
datasetframe=dataset2.drop(['EmployeeCount','EmployeeNumber','Over18','StandardHours'],axis=1)

# %%
datasetframe.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# 0          2               1                        2  Female  ...
# 1          1               1                        3    Male  ...
# 2          2               4                        4    Male  ...
# 3          4               1                        4  Female  ...
# 4          1               3                        1    Male  ...
#
#    RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# ...

# %% [markdown]
# Check P value :

# %%
datasetframe.shape
# Out:
# (1470, 32)

# %%
dataset2.shape
# Out:
# (1470, 36)

# %%
from scipy.stats import pearsonr

# %%
stats,p=pearsonr(datasetframe["Attrition"],datasetframe["Age"])

# %%
print(stats,p)
# Out:
# -0.1592050068657796 8.356308021103691e-10

# %%
stats,p=pearsonr(datasetframe["Attrition"],datasetframe["MonthlyIncome"])

# %%
print(stats,p)
# Out:
# -0.15983958238498872 7.147363985353496e-10

# %%
stats,p=pearsonr(datasetframe["Attrition"],datasetframe["YearsWithCurrManager"])

# %%
print(stats,p)
# Out:
# -0.15619931590162844 1.7369867845242041e-09

# %%
datasetframe.corr()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2268\3181183205.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   datasetframe.corr()
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000  -0.159205        0.024751   0.010661
# Attrition                -0.159205   1.000000        0.000074  -0.056652
# BusinessTravel            0.024751   0.000074        1.000000  -0.004086
# DailyRate                 0.010661  -0.056652       -0.004086   1.000000
# Department               -0.031882   0.063991       -0.009044   0.007109
# DistanceFromHome         -0.001686   0.077924       -0.024469  -0.004985
# Education                 0.208034  -0.031373        0.000757  -0.016806
# EducationField           -0.040873   0.026846        0.023724   0.037709
# ...

# %%
import statsmodels.api as  sm

# %%
import sklearn

# %%
from sklearn.linear_model import LogisticRegression

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# LogisticRegression

# %%
Y=datasetframe.Attrition

# %%
X=datasetframe.drop(["Attrition"],axis=1)

# %%
X1=sm.add_constant(X)

# %%
Logistic=sm.Logit(Y,X1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 Logistic=sm.Logit(Y,X1)
#
# File C:\ProgramData\anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py:462, in BinaryModel.__init__(self, endog, exog, check_rank, **kwargs)
#     459 def __init__(self, endog, exog, check_rank=True, **kwargs):
#     460     # unconditional check, requires no extra kwargs added by subclasses
#     461     self._check_kwargs(kwargs)
# --> 462     super().__init__(endog, exog, check_rank, **kwargs)
#     463     if not issubclass(self.__class__, MultinomialModel):
#     464         if not np.all((self.endog >= 0) & (self.endog <= 1)):
#
# File C:\ProgramData\anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py:178, in DiscreteModel.__init__(self, endog, exog, check_rank, **kwargs)
# ...

# %%
result=Logistic.fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 result=Logistic.fit()
#
# NameError: name 'Logistic' is not defined

# %%
df_cont=datasetframe.select_dtypes(include='int64')
df_cont.columns
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education',
#        'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel',
#        'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# Heatmap for correlation

# %%
import seaborn as sns

# %%
plt.figure(figsize=(30, 30))
sns.heatmap(datasetframe.corr(), annot=True, cmap="RdYlGn", annot_kws={"size":15})
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2268\1205046589.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(datasetframe.corr(), annot=True, cmap="RdYlGn", annot_kws={"size":15})
# <Axes: >

# %%
datasetframe.drop('Attrition', axis=1).corrwith(datasetframe.Attrition).plot(kind='bar', figsize=(15, 10))
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2268\1921547751.py:1: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   datasetframe.drop('Attrition', axis=1).corrwith(datasetframe.Attrition).plot(kind='bar', figsize=(15, 10))
# <Axes: >

# %%
datasetframe_cont=datasetframe.select_dtypes(include='int64')
datasetframe_cont.columns
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education',
#        'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel',
#        'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
plt.figure(figsize=(20, 30))

for i, column in enumerate(datasetframe_cont, 1):
    plt.subplot(8, 3, i)
    datasetframe[datasetframe["Attrition"] == 0][column].hist(bins=35, color='green', label='Attrition = NO', alpha=1)
    datasetframe[datasetframe["Attrition"] == 1][column].hist(bins=35, color='blue', label='Attrition = YES', alpha=1)
    plt.legend()
    plt.ylabel(column)
